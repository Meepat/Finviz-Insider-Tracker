# %% [markdown]
# <a href="https://colab.research.google.com/github/Meepat/Finviz-Insider-Tracker/blob/main/Meet_Finviz_Insider.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Installing the Finviz Library Package**

# %%
pip install pyfinviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pyfinviz: filename=pyfinviz-0.7-py3-none-any.whl size=23247 sha256=5468e4b073782338b2137db658ec1e47d4c2a18cfa289b3fd4920e4aa7c660cd
#   Stored in directory: /root/.cache/pip/wheels/e9/de/35/65e2c5685c8c5d986a22058f178745437eec8da95fd5cd02bd
# ...
#   Created wheel for free-proxy: filename=free_proxy-1.0.6-py3-none-any.whl size=5218 sha256=1d6a12c343b8a07235f7491c38415040c7cbdfa02b42d800c8f854b41506b993
#   Stored in directory: /root/.cache/pip/wheels/36/7d/20/ce38b2a0652cc2e4ad4a1a6088a8f64b655064f11b6ad87ba1
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=e6e3679e1d930c96e9497404407b7b25464522c82fae0dd9408d6c7e5620bfb8
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built pyfinviz free-proxy validators
# ...

# %% [markdown]
# **Printing The Insider Trading Dataframe**

# %%
from pyfinviz.insider import Insider
insider = Insider()
print(insider)
print(insider.table_df)
# Out:
# ...
#     Ticker                           Owner             Relationship    Date  \
# 0     MNMD                   Barrow Robert  Chief Executive Officer  Jun 16
# 1     TCDA  Venrock Healthcare Capital Par                10% Owner  Jun 16
# 2     MTEM                LALANDE KEVIN M.                 Director  Jun 13
# 3     MTEM                LALANDE KEVIN M.                 Director  Jun 14
# 4     MTEM                LALANDE KEVIN M.                 Director  Jun 15
# ..     ...                             ...                      ...     ...
# 195   MDRR                Messier Thomas E              See Remarks  Jun 17
# 196   MDRR          Winn Charles Brent Jr.  Chief Financial Officer  Jun 16
# 197   MDRR          Winn Charles Brent Jr.  Chief Financial Officer  Jun 17
# 198   CMMB                   Marvin Donald  Executive VP, CFO & COO  Mar 16
# 199   DAWN              Blackman Samuel C.    Chief Medical Officer  Jun 15
#
# ...

# %%
insider.table_df
# Out:
#     Ticker                           Owner             Relationship    Date  \
# 0     MNMD                   Barrow Robert  Chief Executive Officer  Jun 16
# 1     TCDA  Venrock Healthcare Capital Par                10% Owner  Jun 16
# 2     MTEM                LALANDE KEVIN M.                 Director  Jun 13
# 3     MTEM                LALANDE KEVIN M.                 Director  Jun 14
# 4     MTEM                LALANDE KEVIN M.                 Director  Jun 15
# ..     ...                             ...                      ...     ...
# 195   MDRR                Messier Thomas E              See Remarks  Jun 17
# 196   MDRR          Winn Charles Brent Jr.  Chief Financial Officer  Jun 16
# 197   MDRR          Winn Charles Brent Jr.  Chief Financial Officer  Jun 17
# 198   CMMB                   Marvin Donald  Executive VP, CFO & COO  Mar 16
# 199   DAWN              Blackman Samuel C.    Chief Medical Officer  Jun 15
#
# ...

# %% [markdown]
# **Exporting The Dataframe Into A CSV File**

# %%
insider.table_df.to_csv('L.csv')
